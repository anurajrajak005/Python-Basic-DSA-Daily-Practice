# %% [markdown]
# ### *order of Growth*

# %%
# order of Growth
# Find relationship between Time & Input
# Asymptotic Notation:

# %% [markdown]
# ### BigO: *Descending order(Worst Case)*
# ### Omega: *Ascending order(Best Case)*
# ### Theta: *Random order(Average Case)*

# %%
#DSA : Constant is negligilble

# %% [markdown]
# ### ADD FUNCTION

# %%
def good(n):
    for i in n:
        k=i+2
        print(k)

# %%
h = [9,4,1,3,6]
good(h)
# Out:
# 11
# 6
# 3
# 5
# 8

# %% [markdown]
# ### Multiple Function

# %%
def good(n):
    for i in n:
        k=i*2
        print(k)

# %%
h = [9,4,1,3,6]
good(h)
# Out:
# 18
# 8
# 2
# 6
# 12
